# %%
from typing import List, Tuple, Optional
import numpy as np

class InventoryEnv:
    """
    Inventory management environment for 3 products with volume constraints, lead times, and stochastic or deterministic demand.

    This environment simulates:
    - Warehouse inventory evolution with lead-time-based ordering.
    - Daily customer demand and fulfillment.
    - Cost computation due to holding, ordering, and stockouts.

    Attributes:
        volume_capacity (float): Max warehouse volume capacity.
        initial_inventory (List[int]): Initial stock for each product.
        product_volumes (List[float]): Volume per unit of each product.
        holding_cost_per_volume (float): Cost per unit volume per day for storing inventory.
        stockout_costs (List[float]): Penalty per unit of unfulfilled demand for each product.
        ordering_costs (List[float]): Fixed cost per order placed for each product.
        discard_costs (List[float]): Cost per unit discarded due to over-capacity.
        lead_times (List[int]): Days before an order arrives for each product.
        simulation_days (int): Episode length in days.
        demand_sequences (Optional[List[List[int]]]): Predefined demand for evaluation.
        demand_lambda (List[float]): Poisson mean for training demand generation.
    """

    def __init__(
        self,
        volume_capacity: float = 1000.0,
        initial_inventory: List[int] = [100, 100, 100],
        product_volumes: List[float] = [2.0, 3.0, 1.5],
        holding_cost_per_volume: float = 5.0,  # Updated holding cost
        stockout_costs: List[float] = [400.0, 500.0, 300.0],
        ordering_costs: List[float] = [80.0, 200.0, 120.0],
        discard_costs: List[float] = [200.0, 250.0, 150.0],  # New discard penalties
        lead_times: List[int] = [3, 2, 1],
        simulation_days: int = 50,
        demand_sequences: Optional[List[List[int]]] = None,
        demand_lambda: List[float] = [30, 25, 35],
        seed: int = 42
    ):
        self.volume_capacity = volume_capacity
        self.initial_inventory = initial_inventory[:]
        self.product_volumes = product_volumes
        self.holding_cost_per_volume = holding_cost_per_volume
        self.stockout_costs = stockout_costs
        self.ordering_costs = ordering_costs
        self.discard_costs = discard_costs
        self.lead_times = lead_times
        self.simulation_days = simulation_days
        self.demand_sequences = demand_sequences
        self.demand_lambda = demand_lambda
        self.random_state = np.random.RandomState(seed)

        self.reset()

    def reset(self) -> List[int]:
        """
        Reset environment to initial state for a new episode.
        Returns the initial observation state.
        """
        self.day = 0
        self.inventory = self.initial_inventory[:] # Resets current inventory to initial inventory
        self.pending_orders = [[] for _ in range(len(self.initial_inventory))]  # list of orders to be delivered (day_due, quantity)
        return self._get_state() # Returns initial state of the environment

    def step(self, action: List[int]) -> Tuple[List[int], float, bool, dict]:
        """
        Executes one simulation step.

        Args:
            action (List[int]): List of order quantities for each product. Each value must be in {0, 10, ..., 100}.

        Returns:
            state (List[int]): Updated state after taking the action.
            reward (float): Scaled negative cost for the step.
            done (bool): True if the episode is over.
            info (dict): Additional information (cost breakdown, demand, fulfillment).
        """
        assert all(a in range(0, 101, 10) for a in action), "Actions must be in {0, 10, ..., 100}" # Invalid actions are rejected

        # 1. Receive due orders and add them to current inventory
        for i in range(3):
            arrivals = [qty for due, qty in self.pending_orders[i] if due == self.day]
            self.inventory[i] += sum(arrivals)
            self.pending_orders[i] = [(due, qty) for due, qty in self.pending_orders[i] if due > self.day]

        # 2. Place new orders and add them to pending orders
        order_cost = 0
        for i in range(3):
            if action[i] > 0:
                order_cost += self.ordering_costs[i]
                self.pending_orders[i].append((self.day + self.lead_times[i], action[i]))

        # 3. Generate demand if not provided
        if self.demand_sequences:
            demand = self.demand_sequences[self.day]
        else:
            demand = [self.random_state.poisson(lam) for lam in self.demand_lambda]

        # 4. Enforce volume capacity and compute discards
        total_volume = sum(self.inventory[i] * self.product_volumes[i] for i in range(3))
        discarded = [0, 0, 0]
        if total_volume > self.volume_capacity:
            overflow = total_volume - self.volume_capacity
            # discard from highest-volume items first
            for i in sorted(range(3), key=lambda j: self.product_volumes[j], reverse=True):
                max_remove = int(overflow // self.product_volumes[i])
                remove_qty = min(max_remove, self.inventory[i])
                discarded[i] = remove_qty
                self.inventory[i] -= remove_qty
                overflow -= remove_qty * self.product_volumes[i]
                if overflow <= 0:
                    break

        # 5. Fulfill demand and compute stockouts
        fulfilled = [min(self.inventory[i], demand[i]) for i in range(3)]
        unfulfilled = [demand[i] - fulfilled[i] for i in range(3)]
        self.inventory = [self.inventory[i] - fulfilled[i] for i in range(3)]

        # 6. Compute costs and reward
        holding_cost = sum(self.inventory[i] * self.product_volumes[i] * self.holding_cost_per_volume for i in range(3))
        stockout_cost = sum(unfulfilled[i] * self.stockout_costs[i] for i in range(3))
        discard_cost = sum(discarded[i] * self.discard_costs[i] for i in range(3))
        total_cost = holding_cost + stockout_cost + order_cost + discard_cost
        reward = - total_cost / 100.0  # scaled for stability

        # 7. Update state
        self.day += 1
        done = self.day >= self.simulation_days # True if episode ends
        info = {
            "day": self.day,
            "inventory": self.inventory[:],
            "fulfilled": fulfilled,
            "unfulfilled": unfulfilled,
            "order_cost": order_cost,
            "holding_cost": holding_cost,
            "stockout_cost": stockout_cost,
            "discard_cost": discard_cost,
            "total_cost": total_cost
        }

        return self._get_state(), reward, done, info

    def _get_state(self) -> List[int]:
        """
        Constructs the state vector including inventory levels and outstanding orders.

        Returns:
            List[int]: State representation with 7 variables
        """
        outstanding_orders = [sum(qty for _, qty in self.pending_orders[i]) for i in range(3)]
        return self.inventory + outstanding_orders + [self.day]

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=128):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

# %%
class DQNAgent:
    def __init__(self, state_size, action_size, gamma=0.99, lr=1e-3,
                 batch_size=64, buffer_size=50000, epsilon_start=1.0,
                 epsilon_end=0.05, epsilon_decay=0.995):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma
        self.batch_size = batch_size
        self.memory = deque(maxlen=buffer_size)
        self.epsilon = epsilon_start
        self.epsilon_min = epsilon_end
        self.epsilon_decay = epsilon_decay

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.qnetwork = QNetwork(state_size, action_size).to(self.device)
        self.target_network = QNetwork(state_size, action_size).to(self.device)
        self.optimizer = optim.Adam(self.qnetwork.parameters(), lr=lr)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.qnetwork(state)
        return torch.argmax(q_values).item()

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).to(self.device)
        rewards = torch.FloatTensor(rewards).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).to(self.device)

        q_values = self.qnetwork(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        next_q_values = self.target_network(next_states).max(1)[0]
        targets = rewards + (self.gamma * next_q_values * (1 - dones))

        loss = nn.MSELoss()(q_values, targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def update_target_network(self):
        self.target_network.load_state_dict(self.qnetwork.state_dict())

# %%
env = InventoryEnv()
state = env.reset()
state_size = len(state)
action_size = 11 ** 3  # since 3 products, each has 11 discrete order options

agent = DQNAgent(state_size, action_size)

episodes = 1000
target_update_freq = 10

for e in range(episodes):
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action_idx = agent.act(state)

        # Convert flat index → 3 product orders
        orders = np.unravel_index(action_idx, (11, 11, 11))
        orders = [o * 10 for o in orders]

        next_state, reward, done, _ = env.step(orders)
        agent.remember(state, action_idx, reward, next_state, done)
        agent.replay()
        state = next_state
        total_reward += reward

    if e % target_update_freq == 0:
        agent.update_target_network()

    print(f"Episode {e}, Total Reward: {total_reward}")
# Out:
# Episode 0, Total Reward: -13929.875000000004
# Episode 1, Total Reward: -17039.749999999996
# Episode 2, Total Reward: -19682.4
# Episode 3, Total Reward: -11543.0
# Episode 4, Total Reward: -11769.499999999998
# Episode 5, Total Reward: -14468.149999999998
# Episode 6, Total Reward: -16684.275000000005
# Episode 7, Total Reward: -16051.825000000003
# Episode 8, Total Reward: -13038.225
# Episode 9, Total Reward: -16289.524999999996
# Episode 10, Total Reward: -17196.3
# Episode 11, Total Reward: -19921.824999999993
# Episode 12, Total Reward: -19771.099999999995
# Episode 13, Total Reward: -17736.775000000005
# Episode 14, Total Reward: -18858.350000000006
# Episode 15, Total Reward: -23339.399999999994
# Episode 16, Total Reward: -20427.324999999997
# Episode 17, Total Reward: -22419.125000000004
# Episode 18, Total Reward: -22590.475000000002
# Episode 19, Total Reward: -18034.550000000007
# Episode 20, Total Reward: -14409.474999999999
# Episode 21, Total Reward: -11910.750000000002
# Episode 22, Total Reward: -19175.674999999996
# Episode 23, Total Reward: -18055.025
# Episode 24, Total Reward: -19529.725000000002
# Episode 25, Total Reward: -21140.0
# Episode 26, Total Reward: -20514.850000000002
# Episode 27, Total Reward: -17950.75
# Episode 28, Total Reward: -16057.15
# Episode 29, Total Reward: -13585.774999999998
# Episode 30, Total Reward: -18756.175000000003
# Episode 31, Total Reward: -12243.825000000003
# Episode 32, Total Reward: -17494.75
# Episode 33, Total Reward: -13072.349999999999
# Episode 34, Total Reward: -16452.024999999998
# Episode 35, Total Reward: -19776.200000000004
# Episode 36, Total Reward: -18468.150000000005
# Episode 37, Total Reward: -17697.174999999996
# Episode 38, Total Reward: -12493.400000000003
# Episode 39, Total Reward: -14563.299999999997
# Episode 40, Total Reward: -17979.175
# Episode 41, Total Reward: -19494.25
# Episode 42, Total Reward: -17681.425
# Episode 43, Total Reward: -12497.749999999996
# Episode 44, Total Reward: -10605.275000000003
# Episode 45, Total Reward: -13365.6
# Episode 46, Total Reward: -11942.125
# Episode 47, Total Reward: -19607.95
# Episode 48, Total Reward: -18968.374999999993
# Episode 49, Total Reward: -15284.024999999996
# Episode 50, Total Reward: -14077.349999999999
# Episode 51, Total Reward: -14856.724999999999
# Episode 52, Total Reward: -12988.300000000003
# Episode 53, Total Reward: -11975.824999999999
# Episode 54, Total Reward: -16663.174999999996
# Episode 55, Total Reward: -13499.075
# Episode 56, Total Reward: -20394.325
# Episode 57, Total Reward: -19297.575
# Episode 58, Total Reward: -14687.800000000005
# Episode 59, Total Reward: -17328.100000000002
# Episode 60, Total Reward: -21568.25
# Episode 61, Total Reward: -22981.874999999996
# Episode 62, Total Reward: -18487.899999999994
# Episode 63, Total Reward: -10685.600000000002
# Episode 64, Total Reward: -17756.900000000005
# Episode 65, Total Reward: -6192.774999999998
# Episode 66, Total Reward: -19242.925
# Episode 67, Total Reward: -11439.400000000001
# Episode 68, Total Reward: -9668.600000000002
# Episode 69, Total Reward: -16638.050000000003
# Episode 70, Total Reward: -17843.449999999993
# Episode 71, Total Reward: -11258.725000000004
# Episode 72, Total Reward: -11920.575
# Episode 73, Total Reward: -22374.899999999998
# Episode 74, Total Reward: -13668.325
# Episode 75, Total Reward: -12386.124999999998
# Episode 76, Total Reward: -24322.775000000005
# Episode 77, Total Reward: -17529.625000000004
# Episode 78, Total Reward: -13032.099999999997
# Episode 79, Total Reward: -16095.15
# Episode 80, Total Reward: -22153.6
# Episode 81, Total Reward: -9360.699999999999
# Episode 82, Total Reward: -15440.650000000001
# Episode 83, Total Reward: -11191.475
# Episode 84, Total Reward: -6458.499999999999
# Episode 85, Total Reward: -17563.600000000002
# Episode 86, Total Reward: -13496.149999999998
# Episode 87, Total Reward: -14283.9
# Episode 88, Total Reward: -10477.949999999997
# Episode 89, Total Reward: -19798.900000000005
# Episode 90, Total Reward: -9268.599999999999
# Episode 91, Total Reward: -8196.275
# Episode 92, Total Reward: -16411.999999999993
# Episode 93, Total Reward: -11060.599999999999
# Episode 94, Total Reward: -8754.825
# Episode 95, Total Reward: -14906.975000000002
# Episode 96, Total Reward: -11540.6
# Episode 97, Total Reward: -11809.225
# Episode 98, Total Reward: -13362.399999999998
# Episode 99, Total Reward: -14440.375000000002
# Episode 100, Total Reward: -7864.8
# Episode 101, Total Reward: -12749.675
# Episode 102, Total Reward: -6367.675
# Episode 103, Total Reward: -13411.324999999999
# Episode 104, Total Reward: -7269.650000000001
# Episode 105, Total Reward: -5451.500000000001
# Episode 106, Total Reward: -4719.299999999999
# Episode 107, Total Reward: -7295.974999999999
# Episode 108, Total Reward: -6086.525
# Episode 109, Total Reward: -6716.825
# Episode 110, Total Reward: -8927.574999999999
# Episode 111, Total Reward: -4464.7
# Episode 112, Total Reward: -7715.3499999999985
# Episode 113, Total Reward: -5673.725
# Episode 114, Total Reward: -20121.700000000004
# Episode 115, Total Reward: -4296.899999999999
# Episode 116, Total Reward: -15644.225
# Episode 117, Total Reward: -4492.15
# Episode 118, Total Reward: -6394.200000000001
# Episode 119, Total Reward: -6759.874999999999
# Episode 120, Total Reward: -2894.8
# Episode 121, Total Reward: -7114.025000000001
# Episode 122, Total Reward: -5451.700000000001
# Episode 123, Total Reward: -4510.550000000001
# Episode 124, Total Reward: -6862.8
# Episode 125, Total Reward: -5366.4
# Episode 126, Total Reward: -4714.325000000001
# Episode 127, Total Reward: -7480.249999999999
# Episode 128, Total Reward: -5168.175
# Episode 129, Total Reward: -7720.574999999999
# Episode 130, Total Reward: -3590.049999999999
# Episode 131, Total Reward: -4792.55
# Episode 132, Total Reward: -4198.724999999999
# Episode 133, Total Reward: -2894.725
# Episode 134, Total Reward: -4380.725
# Episode 135, Total Reward: -4131.7
# Episode 136, Total Reward: -5770.075000000001
# Episode 137, Total Reward: -1835.425
# Episode 138, Total Reward: -3306.175000000001
# Episode 139, Total Reward: -5520.75
# Episode 140, Total Reward: -3267.375
# Episode 141, Total Reward: -9389.375
# Episode 142, Total Reward: -4495.999999999999
# Episode 143, Total Reward: -4585.500000000001
# Episode 144, Total Reward: -8092.275
# Episode 145, Total Reward: -5257.599999999999
# Episode 146, Total Reward: -15366.625
# Episode 147, Total Reward: -5362.200000000001
# Episode 148, Total Reward: -6047.425
# Episode 149, Total Reward: -3596.4999999999995
# Episode 150, Total Reward: -10822.95
# Episode 151, Total Reward: -3256.0249999999996
# Episode 152, Total Reward: -7016.9
# Episode 153, Total Reward: -3162.2249999999995
# Episode 154, Total Reward: -4717.025000000001
# Episode 155, Total Reward: -3164.2499999999995
# Episode 156, Total Reward: -8027.900000000001
# Episode 157, Total Reward: -3386.7750000000005
# Episode 158, Total Reward: -5462.25
# Episode 159, Total Reward: -3217.2000000000003
# Episode 160, Total Reward: -2929.2750000000015
# Episode 161, Total Reward: -5614.299999999999
# Episode 162, Total Reward: -5451.724999999999
# Episode 163, Total Reward: -6829.125000000001
# Episode 164, Total Reward: -6337.475
# Episode 165, Total Reward: -2950.925
# Episode 166, Total Reward: -3940.2499999999986
# Episode 167, Total Reward: -3281.1749999999997
# Episode 168, Total Reward: -2790.6250000000005
# Episode 169, Total Reward: -6382.474999999999
# Episode 170, Total Reward: -2501.1249999999995
# Episode 171, Total Reward: -3454.2999999999993
# Episode 172, Total Reward: -2030.3499999999997
# Episode 173, Total Reward: -8321.875000000002
# Episode 174, Total Reward: -5006.925
# Episode 175, Total Reward: -4222.349999999999
# Episode 176, Total Reward: -2325.1499999999996
# Episode 177, Total Reward: -6309.224999999999
# Episode 178, Total Reward: -6677.575000000003
# Episode 179, Total Reward: -3230.3500000000004
# Episode 180, Total Reward: -2892.1750000000015
# Episode 181, Total Reward: -3450.725
# Episode 182, Total Reward: -4745.125
# Episode 183, Total Reward: -2856.6249999999995
# Episode 184, Total Reward: -3710.2999999999997
# Episode 185, Total Reward: -3399.9500000000007
# Episode 186, Total Reward: -3252.95
# Episode 187, Total Reward: -4228.425000000001
# Episode 188, Total Reward: -5756.175
# Episode 189, Total Reward: -11684.325
# Episode 190, Total Reward: -2308.0750000000003
# Episode 191, Total Reward: -4078.5
# Episode 192, Total Reward: -3307.425
# Episode 193, Total Reward: -3278.6500000000005
# Episode 194, Total Reward: -3382.725
# Episode 195, Total Reward: -3201.574999999999
# Episode 196, Total Reward: -7882.075
# Episode 197, Total Reward: -4214.374999999999
# Episode 198, Total Reward: -4450.325000000001
# Episode 199, Total Reward: -5343.65
# Episode 200, Total Reward: -12083.025000000001
# Episode 201, Total Reward: -4913.000000000001
# Episode 202, Total Reward: -10456.025
# Episode 203, Total Reward: -3290.024999999999
# Episode 204, Total Reward: -1970.625
# Episode 205, Total Reward: -3070.7000000000003
# Episode 206, Total Reward: -11939.799999999997
# Episode 207, Total Reward: -4420.375000000001
# Episode 208, Total Reward: -6571.65
# Episode 209, Total Reward: -11684.650000000001
# Episode 210, Total Reward: -4563.349999999999
# Episode 211, Total Reward: -9718.499999999996
# Episode 212, Total Reward: -5852.65
# Episode 213, Total Reward: -10076.45
# Episode 214, Total Reward: -4695.500000000001
# Episode 215, Total Reward: -3019.3499999999985
# Episode 216, Total Reward: -5655.249999999999
# Episode 217, Total Reward: -2408.274999999999
# Episode 218, Total Reward: -2427.425
# Episode 219, Total Reward: -7118.749999999999
# Episode 220, Total Reward: -10813.050000000001
# Episode 221, Total Reward: -11535.350000000004
# Episode 222, Total Reward: -3795.7000000000003
# Episode 223, Total Reward: -4050.974999999999
# Episode 224, Total Reward: -5380.125000000005
# Episode 225, Total Reward: -1930.5499999999997
# Episode 226, Total Reward: -3111.4000000000005
# Episode 227, Total Reward: -2147.925
# Episode 228, Total Reward: -2416.2500000000005
# Episode 229, Total Reward: -1843.1250000000002
# Episode 230, Total Reward: -1862.1750000000002
# Episode 231, Total Reward: -4113.525
# Episode 232, Total Reward: -2212.3500000000004
# Episode 233, Total Reward: -2954.925
# Episode 234, Total Reward: -2538.0999999999995
# Episode 235, Total Reward: -2294.425
# Episode 236, Total Reward: -2247.000000000001
# Episode 237, Total Reward: -9881.925
# Episode 238, Total Reward: -8440.175
# Episode 239, Total Reward: -1972.3500000000006
# Episode 240, Total Reward: -9138.975
# Episode 241, Total Reward: -2084.8
# Episode 242, Total Reward: -4027.8499999999995
# Episode 243, Total Reward: -2714.150000000001
# Episode 244, Total Reward: -2716.2
# Episode 245, Total Reward: -2332.674999999999
# Episode 246, Total Reward: -4053.4
# Episode 247, Total Reward: -2588.4500000000003
# Episode 248, Total Reward: -4810.525000000002
# Episode 249, Total Reward: -2380.599999999999
# Episode 250, Total Reward: -5607.450000000001
# Episode 251, Total Reward: -2342.3749999999995
# Episode 252, Total Reward: -4173.300000000001
# Episode 253, Total Reward: -2503.2250000000004
# Episode 254, Total Reward: -2088.475
# Episode 255, Total Reward: -5311.599999999999
# Episode 256, Total Reward: -2910.2
# Episode 257, Total Reward: -3335.200000000001
# Episode 258, Total Reward: -2138.7
# Episode 259, Total Reward: -2893.799999999999
# Episode 260, Total Reward: -2237.725
# Episode 261, Total Reward: -4995.325000000001
# Episode 262, Total Reward: -6721.025000000001
# Episode 263, Total Reward: -3477.650000000001
# Episode 264, Total Reward: -3258.275
# Episode 265, Total Reward: -3786.649999999999
# Episode 266, Total Reward: -3074.975
# Episode 267, Total Reward: -3477.8500000000004
# Episode 268, Total Reward: -2596.2750000000005
# Episode 269, Total Reward: -3779.124999999999
# Episode 270, Total Reward: -6922.35
# Episode 271, Total Reward: -4271.525
# Episode 272, Total Reward: -2031.0999999999997
# Episode 273, Total Reward: -2832.6749999999997
# Episode 274, Total Reward: -1717.7499999999995
# Episode 275, Total Reward: -3490.6500000000005
# Episode 276, Total Reward: -2909.5
# Episode 277, Total Reward: -4621.400000000002
# Episode 278, Total Reward: -4891.074999999999
# Episode 279, Total Reward: -2838.3500000000004
# Episode 280, Total Reward: -2520.125000000001
# Episode 281, Total Reward: -2670.875000000001
# Episode 282, Total Reward: -2440.175
# Episode 283, Total Reward: -5188.725000000001
# Episode 284, Total Reward: -3006.2000000000003
# Episode 285, Total Reward: -3723.4
# Episode 286, Total Reward: -2930.3749999999995
# Episode 287, Total Reward: -3198.8500000000004
# Episode 288, Total Reward: -2312.4
# Episode 289, Total Reward: -2065.6250000000005
# Episode 290, Total Reward: -2683.9999999999995
# Episode 291, Total Reward: -2112.5999999999995
# Episode 292, Total Reward: -5875.0
# Episode 293, Total Reward: -10042.650000000003
# Episode 294, Total Reward: -2451.55
# Episode 295, Total Reward: -2480.8750000000005
# Episode 296, Total Reward: -1763.8749999999995
# Episode 297, Total Reward: -3831.7999999999993
# Episode 298, Total Reward: -2163.5999999999995
# Episode 299, Total Reward: -2634.4999999999995
# Episode 300, Total Reward: -2373.5499999999997
# Episode 301, Total Reward: -2572.7000000000003
# Episode 302, Total Reward: -1896.225
# Episode 303, Total Reward: -3289.2750000000005
# Episode 304, Total Reward: -2044.425
# Episode 305, Total Reward: -2748.775
# Episode 306, Total Reward: -1705.5249999999999
# Episode 307, Total Reward: -2100.6
# Episode 308, Total Reward: -2763.749999999999
# Episode 309, Total Reward: -3207.0
# Episode 310, Total Reward: -2368.0500000000006
# Episode 311, Total Reward: -2861.075
# Episode 312, Total Reward: -2623.9249999999997
# Episode 313, Total Reward: -2374.1000000000004
# Episode 314, Total Reward: -2842.6250000000005
# Episode 315, Total Reward: -2430.775
# Episode 316, Total Reward: -3095.9999999999986
# Episode 317, Total Reward: -1864.7499999999998
# Episode 318, Total Reward: -2906.775
# Episode 319, Total Reward: -2739.3999999999996
# Episode 320, Total Reward: -3252.7499999999995
# Episode 321, Total Reward: -2346.0250000000005
# Episode 322, Total Reward: -2704.4499999999994
# Episode 323, Total Reward: -3494.2999999999993
# Episode 324, Total Reward: -1652.85
# Episode 325, Total Reward: -2543.225
# Episode 326, Total Reward: -2962.4249999999993
# Episode 327, Total Reward: -2905.8000000000006
# Episode 328, Total Reward: -2049.25
# Episode 329, Total Reward: -2556.5999999999995
# Episode 330, Total Reward: -2216.6500000000005
# Episode 331, Total Reward: -2307.55
# Episode 332, Total Reward: -2023.2249999999997
# Episode 333, Total Reward: -1628.8000000000004
# Episode 334, Total Reward: -2290.325
# Episode 335, Total Reward: -2596.574999999999
# Episode 336, Total Reward: -2155.5999999999995
# Episode 337, Total Reward: -2548.25
# Episode 338, Total Reward: -1677.625
# Episode 339, Total Reward: -1692.1000000000001
# Episode 340, Total Reward: -3017.0999999999995
# Episode 341, Total Reward: -2656.6249999999995
# Episode 342, Total Reward: -3041.175
# Episode 343, Total Reward: -3253.575
# Episode 344, Total Reward: -1862.375
# Episode 345, Total Reward: -1851.8249999999998
# Episode 346, Total Reward: -2207.675
# Episode 347, Total Reward: -2164.1499999999996
# Episode 348, Total Reward: -2695.8750000000005
# Episode 349, Total Reward: -3825.175
# Episode 350, Total Reward: -5191.25
# Episode 351, Total Reward: -2373.0499999999997
# Episode 352, Total Reward: -3433.5999999999985
# Episode 353, Total Reward: -2895.2
# Episode 354, Total Reward: -2541.3000000000006
# Episode 355, Total Reward: -4427.950000000001
# Episode 356, Total Reward: -3278.6000000000017
# Episode 357, Total Reward: -5806.274999999999
# Episode 358, Total Reward: -3117.525
# Episode 359, Total Reward: -2646.65
# Episode 360, Total Reward: -2201.5750000000003
# Episode 361, Total Reward: -2744.975
# Episode 362, Total Reward: -1967.2999999999995
# Episode 363, Total Reward: -2348.0499999999997
# Episode 364, Total Reward: -2979.6750000000015
# Episode 365, Total Reward: -3037.075000000001
# Episode 366, Total Reward: -2480.15
# Episode 367, Total Reward: -2489.1000000000004
# Episode 368, Total Reward: -2413.5249999999987
# Episode 369, Total Reward: -2775.65
# Episode 370, Total Reward: -2582.7999999999993
# Episode 371, Total Reward: -3848.075
# Episode 372, Total Reward: -2016.4999999999998
# Episode 373, Total Reward: -2349.499999999999
# Episode 374, Total Reward: -3146.1749999999997
# Episode 375, Total Reward: -3189.9500000000003
# Episode 376, Total Reward: -3366.825
# Episode 377, Total Reward: -2196.8750000000005
# Episode 378, Total Reward: -2473.1749999999993
# Episode 379, Total Reward: -2544.650000000001
# Episode 380, Total Reward: -3676.449999999999
# Episode 381, Total Reward: -4726.550000000001
# Episode 382, Total Reward: -4570.8
# Episode 383, Total Reward: -7945.825000000002
# Episode 384, Total Reward: -2509.4249999999993
# Episode 385, Total Reward: -3021.975000000001
# Episode 386, Total Reward: -2951.1
# Episode 387, Total Reward: -2507.8749999999995
# Episode 388, Total Reward: -3932.7749999999996
# Episode 389, Total Reward: -4597.075000000001
# Episode 390, Total Reward: -2796.2
# Episode 391, Total Reward: -4062.5499999999993
# Episode 392, Total Reward: -2236.45
# Episode 393, Total Reward: -2672.7499999999995
# Episode 394, Total Reward: -2212.55
# Episode 395, Total Reward: -2102.175
# Episode 396, Total Reward: -2162.475000000001
# Episode 397, Total Reward: -3437.3249999999994
# Episode 398, Total Reward: -2676.0000000000005
# Episode 399, Total Reward: -1868.0749999999996
# Episode 400, Total Reward: -3634.9750000000004
# Episode 401, Total Reward: -2686.2749999999996
# Episode 402, Total Reward: -2405.775
# Episode 403, Total Reward: -3103.4250000000006
# Episode 404, Total Reward: -2562.8999999999996
# Episode 405, Total Reward: -6303.575000000002
# Episode 406, Total Reward: -5933.225000000001
# Episode 407, Total Reward: -2548.675
# Episode 408, Total Reward: -2604.1500000000005
# Episode 409, Total Reward: -1939.225
# Episode 410, Total Reward: -1948.3499999999992
# Episode 411, Total Reward: -3886.799999999999
# Episode 412, Total Reward: -7819.975000000001
# Episode 413, Total Reward: -6337.224999999999
# Episode 414, Total Reward: -2162.8249999999994
# Episode 415, Total Reward: -2326.65
# Episode 416, Total Reward: -2595.6249999999995
# Episode 417, Total Reward: -3945.7
# Episode 418, Total Reward: -2519.7999999999997
# Episode 419, Total Reward: -3134.4
# Episode 420, Total Reward: -7703.524999999999
# Episode 421, Total Reward: -1852.8500000000001
# Episode 422, Total Reward: -2563.8000000000006
# Episode 423, Total Reward: -4614.65
# Episode 424, Total Reward: -9786.6
# Episode 425, Total Reward: -5354.550000000001
# Episode 426, Total Reward: -3180.0
# Episode 427, Total Reward: -10623.974999999997
# Episode 428, Total Reward: -6162.575
# Episode 429, Total Reward: -2032.575
# Episode 430, Total Reward: -2854.725000000001
# Episode 431, Total Reward: -2430.1499999999996
# Episode 432, Total Reward: -3216.099999999999
# Episode 433, Total Reward: -7483.475
# Episode 434, Total Reward: -2024.8999999999996
# Episode 435, Total Reward: -2719.2499999999986
# Episode 436, Total Reward: -2450.575
# Episode 437, Total Reward: -10817.225
# Episode 438, Total Reward: -7585.25
# Episode 439, Total Reward: -2556.149999999999
# Episode 440, Total Reward: -2731.0999999999995
# Episode 441, Total Reward: -3902.9249999999997
# Episode 442, Total Reward: -3073.250000000001
# Episode 443, Total Reward: -3918.7999999999997
# Episode 444, Total Reward: -2650.075
# Episode 445, Total Reward: -2870.8499999999995
# Episode 446, Total Reward: -2579.225
# Episode 447, Total Reward: -2815.175
# Episode 448, Total Reward: -3634.35
# Episode 449, Total Reward: -4072.475000000001
# Episode 450, Total Reward: -3451.15
# Episode 451, Total Reward: -2809.0499999999993
# Episode 452, Total Reward: -2581.5500000000006
# Episode 453, Total Reward: -2082.3999999999996
# Episode 454, Total Reward: -2811.05
# Episode 455, Total Reward: -3056.975
# Episode 456, Total Reward: -2672.45
# Episode 457, Total Reward: -2624.475
# Episode 458, Total Reward: -1921.75
# Episode 459, Total Reward: -2095.975000000001
# Episode 460, Total Reward: -2990.950000000001
# Episode 461, Total Reward: -1794.9750000000001
# Episode 462, Total Reward: -1857.4750000000001
# Episode 463, Total Reward: -2670.3999999999996
# Episode 464, Total Reward: -2202.749999999999
# Episode 465, Total Reward: -2400.9749999999995
# Episode 466, Total Reward: -11773.3
# Episode 467, Total Reward: -3899.299999999999
# Episode 468, Total Reward: -7083.675
# Episode 469, Total Reward: -12286.199999999999
# Episode 470, Total Reward: -26610.799999999996
# Episode 471, Total Reward: -2472.5000000000005
# Episode 472, Total Reward: -3213.1
# Episode 473, Total Reward: -3629.2749999999996
# Episode 474, Total Reward: -3829.5250000000005
# Episode 475, Total Reward: -3788.9499999999994
# Episode 476, Total Reward: -2629.05
# Episode 477, Total Reward: -2517.1749999999993
# Episode 478, Total Reward: -14930.674999999997
# Episode 479, Total Reward: -4908.8
# Episode 480, Total Reward: -9216.375000000002
# Episode 481, Total Reward: -2247.050000000001
# Episode 482, Total Reward: -2526.85
# Episode 483, Total Reward: -1782.7749999999999
# Episode 484, Total Reward: -2432.6249999999995
# Episode 485, Total Reward: -2243.925000000001
# Episode 486, Total Reward: -2610.0000000000005
# Episode 487, Total Reward: -3986.4750000000004
# Episode 488, Total Reward: -2770.4249999999997
# Episode 489, Total Reward: -5986.549999999999
# Episode 490, Total Reward: -3346.1249999999995
# Episode 491, Total Reward: -2410.8
# Episode 492, Total Reward: -2444.2750000000005
# Episode 493, Total Reward: -2537.6750000000006
# Episode 494, Total Reward: -3087.675
# Episode 495, Total Reward: -3639.325
# Episode 496, Total Reward: -4297.275000000001
# Episode 497, Total Reward: -3184.6749999999997
# Episode 498, Total Reward: -2208.1499999999996
# Episode 499, Total Reward: -4812.925
# Episode 500, Total Reward: -2387.4249999999997
# Episode 501, Total Reward: -2710.475
# Episode 502, Total Reward: -2120.2000000000003
# Episode 503, Total Reward: -2412.2
# Episode 504, Total Reward: -2317.7
# Episode 505, Total Reward: -2643.7500000000005
# Episode 506, Total Reward: -3855.2
# Episode 507, Total Reward: -6373.650000000001
# Episode 508, Total Reward: -2177.675
# Episode 509, Total Reward: -2056.4500000000003
# Episode 510, Total Reward: -6502.599999999999
# Episode 511, Total Reward: -11368.624999999996
# Episode 512, Total Reward: -2912.2000000000003
# Episode 513, Total Reward: -2526.175
# Episode 514, Total Reward: -2721.525
# Episode 515, Total Reward: -4440.875
# Episode 516, Total Reward: -2045.9500000000005
# Episode 517, Total Reward: -1998.675
# Episode 518, Total Reward: -2876.9750000000004
# Episode 519, Total Reward: -2352.5500000000006
# Episode 520, Total Reward: -2851.175
# Episode 521, Total Reward: -2302.0499999999993
# Episode 522, Total Reward: -2649.1000000000004
# Episode 523, Total Reward: -1994.65
# Episode 524, Total Reward: -2110.525
# Episode 525, Total Reward: -2016.4000000000008
# Episode 526, Total Reward: -4624.425000000002
# Episode 527, Total Reward: -2434.5750000000003
# Episode 528, Total Reward: -2366.4
# Episode 529, Total Reward: -2395.175
# Episode 530, Total Reward: -2888.4500000000003
# Episode 531, Total Reward: -3334.6250000000005
# Episode 532, Total Reward: -2675.5
# Episode 533, Total Reward: -9481.599999999999
# Episode 534, Total Reward: -2590.025000000001
# Episode 535, Total Reward: -2087.6249999999995
# Episode 536, Total Reward: -4278.525
# Episode 537, Total Reward: -2403.1250000000005
# Episode 538, Total Reward: -2538.775
# Episode 539, Total Reward: -3393.574999999999
# Episode 540, Total Reward: -1992.6499999999999
# Episode 541, Total Reward: -3441.5749999999994
# Episode 542, Total Reward: -2262.4750000000004
# Episode 543, Total Reward: -2877.1
# Episode 544, Total Reward: -7760.150000000002
# Episode 545, Total Reward: -1964.9500000000003
# Episode 546, Total Reward: -8341.25
# Episode 547, Total Reward: -3571.8250000000003
# Episode 548, Total Reward: -2063.2500000000005
# Episode 549, Total Reward: -5670.575000000001
# Episode 550, Total Reward: -7928.149999999998
# Episode 551, Total Reward: -3000.5499999999997
# Episode 552, Total Reward: -2826.6749999999993
# Episode 553, Total Reward: -12802.100000000004
# Episode 554, Total Reward: -8549.7
# Episode 555, Total Reward: -2884.35
# Episode 556, Total Reward: -2027.6999999999996
# Episode 557, Total Reward: -4943.674999999998
# Episode 558, Total Reward: -2590.425
# Episode 559, Total Reward: -2335.3999999999996
# Episode 560, Total Reward: -5091.924999999997
# Episode 561, Total Reward: -9332.300000000003
# Episode 562, Total Reward: -3017.675
# Episode 563, Total Reward: -2730.724999999999
# Episode 564, Total Reward: -2426.3999999999996
# Episode 565, Total Reward: -2682.275
# Episode 566, Total Reward: -5112.350000000001
# Episode 567, Total Reward: -6785.074999999999
# Episode 568, Total Reward: -2472.1999999999994
# Episode 569, Total Reward: -1708.5500000000002
# Episode 570, Total Reward: -2370.0249999999996
# Episode 571, Total Reward: -2476.725
# Episode 572, Total Reward: -2790.2749999999996
# Episode 573, Total Reward: -2307.65
# Episode 574, Total Reward: -1840.5500000000004
# Episode 575, Total Reward: -1958.9749999999995
# Episode 576, Total Reward: -3345.75
# Episode 577, Total Reward: -2310.0750000000003
# Episode 578, Total Reward: -4515.674999999999
# Episode 579, Total Reward: -2410.2249999999995
# Episode 580, Total Reward: -1540.4750000000001
# Episode 581, Total Reward: -2387.2999999999997
# Episode 582, Total Reward: -2224.225000000001
# Episode 583, Total Reward: -3395.7500000000014
# Episode 584, Total Reward: -2396.5000000000005
# Episode 585, Total Reward: -2551.3
# Episode 586, Total Reward: -3236.8000000000006
# Episode 587, Total Reward: -2246.675
# Episode 588, Total Reward: -3291.0000000000005
# Episode 589, Total Reward: -3201.4249999999993
# Episode 590, Total Reward: -4362.500000000001
# Episode 591, Total Reward: -2068.4249999999997
# Episode 592, Total Reward: -3592.0750000000003
# Episode 593, Total Reward: -3300.8750000000005
# Episode 594, Total Reward: -1824.35
# Episode 595, Total Reward: -2537.2749999999996
# Episode 596, Total Reward: -2720.9249999999997
# Episode 597, Total Reward: -3485.4999999999995
# Episode 598, Total Reward: -7399.6500000000015
# Episode 599, Total Reward: -2412.4499999999994
# Episode 600, Total Reward: -1882.725
# Episode 601, Total Reward: -2075.2749999999996
# Episode 602, Total Reward: -2479.525
# Episode 603, Total Reward: -8277.575
# Episode 604, Total Reward: -5318.150000000001
# Episode 605, Total Reward: -1934.3249999999994
# Episode 606, Total Reward: -2445.8250000000003
# Episode 607, Total Reward: -3733.625000000001
# Episode 608, Total Reward: -8853.425
# Episode 609, Total Reward: -2812.8749999999995
# Episode 610, Total Reward: -10691.0
# Episode 611, Total Reward: -8814.275000000001
# Episode 612, Total Reward: -1822.8999999999999
# Episode 613, Total Reward: -1852.0000000000005
# Episode 614, Total Reward: -5560.725
# Episode 615, Total Reward: -3329.250000000001
# Episode 616, Total Reward: -8436.624999999998
# Episode 617, Total Reward: -2915.3249999999994
# Episode 618, Total Reward: -2315.9
# Episode 619, Total Reward: -3288.325
# Episode 620, Total Reward: -3876.425
# Episode 621, Total Reward: -2425.1750000000006
# Episode 622, Total Reward: -1811.5750000000003
# Episode 623, Total Reward: -2202.6749999999997
# Episode 624, Total Reward: -2088.9250000000006
# Episode 625, Total Reward: -2677.400000000001
# Episode 626, Total Reward: -2497.324999999999
# Episode 627, Total Reward: -1609.6999999999996
# Episode 628, Total Reward: -2510.6
# Episode 629, Total Reward: -7018.775000000002
# Episode 630, Total Reward: -9726.375
# Episode 631, Total Reward: -3040.1
# Episode 632, Total Reward: -3004.0499999999997
# Episode 633, Total Reward: -2795.5000000000005
# Episode 634, Total Reward: -3436.675
# Episode 635, Total Reward: -2251.5750000000007
# Episode 636, Total Reward: -2779.125
# Episode 637, Total Reward: -2451.0
# Episode 638, Total Reward: -2873.2999999999993
# Episode 639, Total Reward: -2201.2999999999997
# Episode 640, Total Reward: -3922.650000000002
# Episode 641, Total Reward: -3118.9
# Episode 642, Total Reward: -2416.55
# Episode 643, Total Reward: -2251.35
# Episode 644, Total Reward: -2530.3000000000006
# Episode 645, Total Reward: -2305.8
# Episode 646, Total Reward: -2486.0750000000003
# Episode 647, Total Reward: -10178.074999999995
# Episode 648, Total Reward: -6921.375000000001
# Episode 649, Total Reward: -2127.1749999999993
# Episode 650, Total Reward: -3177.7999999999997
# Episode 651, Total Reward: -1728.775
# Episode 652, Total Reward: -1973.2
# Episode 653, Total Reward: -1760.3249999999998
# Episode 654, Total Reward: -1582.1249999999993
# Episode 655, Total Reward: -1936.6999999999996
# Episode 656, Total Reward: -2789.4999999999995
# Episode 657, Total Reward: -3080.7500000000005
# Episode 658, Total Reward: -2577.7500000000005
# Episode 659, Total Reward: -1668.0
# Episode 660, Total Reward: -3044.825
# Episode 661, Total Reward: -3500.6999999999994
# Episode 662, Total Reward: -2667.3000000000006
# Episode 663, Total Reward: -2850.6750000000006
# Episode 664, Total Reward: -2874.350000000001
# Episode 665, Total Reward: -4339.175
# Episode 666, Total Reward: -2130.8750000000005
# Episode 667, Total Reward: -1844.65
# Episode 668, Total Reward: -3074.150000000001
# Episode 669, Total Reward: -3067.0
# Episode 670, Total Reward: -2804.7250000000004
# Episode 671, Total Reward: -1702.225
# Episode 672, Total Reward: -2180.2499999999995
# Episode 673, Total Reward: -4340.925000000001
# Episode 674, Total Reward: -3789.7750000000005
# Episode 675, Total Reward: -1610.8250000000005
# Episode 676, Total Reward: -2067.2749999999996
# Episode 677, Total Reward: -2384.2
# Episode 678, Total Reward: -2180.2500000000005
# Episode 679, Total Reward: -1896.9
# Episode 680, Total Reward: -2348.9999999999995
# Episode 681, Total Reward: -5377.525
# Episode 682, Total Reward: -1774.3
# Episode 683, Total Reward: -1755.2249999999997
# Episode 684, Total Reward: -11232.95
# Episode 685, Total Reward: -1926.3
# Episode 686, Total Reward: -2620.55
# Episode 687, Total Reward: -2048.6500000000005
# Episode 688, Total Reward: -2411.9000000000005
# Episode 689, Total Reward: -2193.575
# Episode 690, Total Reward: -2136.9000000000005
# Episode 691, Total Reward: -1563.8249999999998
# Episode 692, Total Reward: -1612.9750000000001
# Episode 693, Total Reward: -1856.8250000000003
# Episode 694, Total Reward: -2361.9499999999994
# Episode 695, Total Reward: -3827.475000000001
# Episode 696, Total Reward: -3083.65
# Episode 697, Total Reward: -3464.275
# Episode 698, Total Reward: -1757.925
# Episode 699, Total Reward: -1745.8000000000002
# Episode 700, Total Reward: -1919.1000000000006
# Episode 701, Total Reward: -2829.975
# Episode 702, Total Reward: -1763.825
# Episode 703, Total Reward: -2079.525
# Episode 704, Total Reward: -7426.325000000001
# Episode 705, Total Reward: -3495.325
# Episode 706, Total Reward: -2550.0249999999996
# Episode 707, Total Reward: -2143.0750000000003
# Episode 708, Total Reward: -1910.6250000000005
# Episode 709, Total Reward: -1972.5749999999998
# Episode 710, Total Reward: -4005.375
# Episode 711, Total Reward: -1847.05
# Episode 712, Total Reward: -1962.6749999999993
# Episode 713, Total Reward: -2052.9750000000004
# Episode 714, Total Reward: -1811.5500000000004
# Episode 715, Total Reward: -2016.9999999999998
# Episode 716, Total Reward: -1716.075
# Episode 717, Total Reward: -1709.6000000000004
# Episode 718, Total Reward: -1880.1499999999992
# Episode 719, Total Reward: -3668.0500000000006
# Episode 720, Total Reward: -1933.4499999999998
# Episode 721, Total Reward: -1969.8500000000001
# Episode 722, Total Reward: -1729.9250000000004
# Episode 723, Total Reward: -1624.3500000000001
# Episode 724, Total Reward: -1187.3
# Episode 725, Total Reward: -1864.6749999999997
# Episode 726, Total Reward: -1839.7499999999998
# Episode 727, Total Reward: -1428.7749999999994
# Episode 728, Total Reward: -1683.8250000000005
# Episode 729, Total Reward: -1798.6999999999998
# Episode 730, Total Reward: -1757.0750000000005
# Episode 731, Total Reward: -1530.7499999999998
# Episode 732, Total Reward: -2439.3
# Episode 733, Total Reward: -2248.525
# Episode 734, Total Reward: -1840.6000000000001
# Episode 735, Total Reward: -14889.900000000005
# Episode 736, Total Reward: -4218.0250000000015
# Episode 737, Total Reward: -4533.099999999999
# Episode 738, Total Reward: -4346.325000000001
# Episode 739, Total Reward: -1829.2749999999996
# Episode 740, Total Reward: -2387.7249999999995
# Episode 741, Total Reward: -1830.7249999999995
# Episode 742, Total Reward: -1803.9250000000004
# Episode 743, Total Reward: -2173.6500000000005
# Episode 744, Total Reward: -2052.275
# Episode 745, Total Reward: -2074.3
# Episode 746, Total Reward: -1613.8500000000001
# Episode 747, Total Reward: -2452.0
# Episode 748, Total Reward: -3086.1749999999997
# Episode 749, Total Reward: -2133.9750000000004
# Episode 750, Total Reward: -2126.600000000001
# Episode 751, Total Reward: -3300.150000000001
# Episode 752, Total Reward: -2017.0249999999994
# Episode 753, Total Reward: -1831.7250000000001
# Episode 754, Total Reward: -3827.3750000000014
# Episode 755, Total Reward: -2013.8
# Episode 756, Total Reward: -4708.950000000001
# Episode 757, Total Reward: -2037.1000000000004
# Episode 758, Total Reward: -1830.5749999999996
# Episode 759, Total Reward: -2978.15
# Episode 760, Total Reward: -2462.824999999999
# Episode 761, Total Reward: -1394.5249999999999
# Episode 762, Total Reward: -1962.7499999999998
# Episode 763, Total Reward: -1747.2000000000005
# Episode 764, Total Reward: -1682.3250000000003
# Episode 765, Total Reward: -2144.125
# Episode 766, Total Reward: -1728.95
# Episode 767, Total Reward: -2948.7749999999996
# Episode 768, Total Reward: -2006.9999999999998
# Episode 769, Total Reward: -2409.0249999999996
# Episode 770, Total Reward: -2104.7249999999995
# Episode 771, Total Reward: -1770.1250000000005
# Episode 772, Total Reward: -2003.3499999999992
# Episode 773, Total Reward: -1922.7749999999996
# Episode 774, Total Reward: -1628.6499999999994
# Episode 775, Total Reward: -2513.5499999999993
# Episode 776, Total Reward: -1445.2249999999997
# Episode 777, Total Reward: -2138.1500000000005
# Episode 778, Total Reward: -2090.5
# Episode 779, Total Reward: -1662.85
# Episode 780, Total Reward: -1710.2749999999999
# Episode 781, Total Reward: -1724.6249999999998
# Episode 782, Total Reward: -1742.6249999999998
# Episode 783, Total Reward: -3107.9750000000004
# Episode 784, Total Reward: -3023.400000000001
# Episode 785, Total Reward: -3710.1999999999994
# Episode 786, Total Reward: -2263.725000000001
# Episode 787, Total Reward: -1527.8500000000001
# Episode 788, Total Reward: -2264.925
# Episode 789, Total Reward: -1834.1000000000001
# Episode 790, Total Reward: -2559.5499999999997
# Episode 791, Total Reward: -2183.0
# Episode 792, Total Reward: -1939.7750000000003
# Episode 793, Total Reward: -2479.7749999999996
# Episode 794, Total Reward: -1860.6249999999995
# Episode 795, Total Reward: -1536.45
# Episode 796, Total Reward: -1977.45
# Episode 797, Total Reward: -1556.5250000000003
# Episode 798, Total Reward: -2096.6749999999997
# Episode 799, Total Reward: -2272.2999999999993
# Episode 800, Total Reward: -1495.2000000000003
# Episode 801, Total Reward: -1903.2499999999998
# Episode 802, Total Reward: -1902.5000000000005
# Episode 803, Total Reward: -4918.275
# Episode 804, Total Reward: -2917.0499999999997
# Episode 805, Total Reward: -1712.7750000000003
# Episode 806, Total Reward: -4268.65
# Episode 807, Total Reward: -1566.6249999999998
# Episode 808, Total Reward: -1729.65
# Episode 809, Total Reward: -1680.9999999999998
# Episode 810, Total Reward: -2622.1499999999996
# Episode 811, Total Reward: -1564.0250000000005
# Episode 812, Total Reward: -1796.0750000000003
# Episode 813, Total Reward: -1555.3749999999998
# Episode 814, Total Reward: -2394.4750000000004
# Episode 815, Total Reward: -7913.124999999999
# Episode 816, Total Reward: -10075.450000000003
# Episode 817, Total Reward: -4155.399999999999
# Episode 818, Total Reward: -2379.375
# Episode 819, Total Reward: -2573.85
# Episode 820, Total Reward: -2975.775
# Episode 821, Total Reward: -1743.325
# Episode 822, Total Reward: -1489.825
# Episode 823, Total Reward: -1609.35
# Episode 824, Total Reward: -2305.05
# Episode 825, Total Reward: -1985.175
# Episode 826, Total Reward: -2163.1250000000005
# Episode 827, Total Reward: -2732.1249999999995
# Episode 828, Total Reward: -1697.3249999999991
# Episode 829, Total Reward: -1570.5249999999999
# Episode 830, Total Reward: -1435.45
# Episode 831, Total Reward: -1554.025
# Episode 832, Total Reward: -1510.2999999999997
# Episode 833, Total Reward: -1662.325
# Episode 834, Total Reward: -2927.1250000000005
# Episode 835, Total Reward: -1896.525
# Episode 836, Total Reward: -1903.9750000000001
# Episode 837, Total Reward: -1932.3499999999995
# Episode 838, Total Reward: -1996.6499999999996
# Episode 839, Total Reward: -3213.1749999999997
# Episode 840, Total Reward: -2173.9000000000005
# Episode 841, Total Reward: -6274.25
# Episode 842, Total Reward: -1806.7000000000003
# Episode 843, Total Reward: -2305.4
# Episode 844, Total Reward: -1661.1999999999996
# Episode 845, Total Reward: -1649.4
# Episode 846, Total Reward: -1918.2749999999999
# Episode 847, Total Reward: -2262.1250000000005
# Episode 848, Total Reward: -1208.8249999999996
# Episode 849, Total Reward: -1327.5500000000002
# Episode 850, Total Reward: -1696.8250000000005
# Episode 851, Total Reward: -1541.525
# Episode 852, Total Reward: -1658.5500000000002
# Episode 853, Total Reward: -1506.125
# Episode 854, Total Reward: -1746.2249999999995
# Episode 855, Total Reward: -1604.5500000000002
# Episode 856, Total Reward: -1158.1750000000002
# Episode 857, Total Reward: -1890.2250000000001
# Episode 858, Total Reward: -1628.6250000000005
# Episode 859, Total Reward: -1834.0999999999995
# Episode 860, Total Reward: -1735.0249999999996
# Episode 861, Total Reward: -1513.8999999999994
# Episode 862, Total Reward: -1186.95
# Episode 863, Total Reward: -1784.6999999999998
# Episode 864, Total Reward: -1323.9750000000008
# Episode 865, Total Reward: -1987.1000000000001
# Episode 866, Total Reward: -1627.3249999999998
# Episode 867, Total Reward: -1810.7249999999997
# Episode 868, Total Reward: -2030.6250000000007
# Episode 869, Total Reward: -2035.45
# Episode 870, Total Reward: -1777.7499999999998
# Episode 871, Total Reward: -1820.775
# Episode 872, Total Reward: -1504.325
# Episode 873, Total Reward: -1967.3999999999994
# Episode 874, Total Reward: -1742.425
# Episode 875, Total Reward: -1372.975
# Episode 876, Total Reward: -1113.6249999999998
# Episode 877, Total Reward: -1778.775
# Episode 878, Total Reward: -1196.8999999999999
# Episode 879, Total Reward: -1571.6749999999995
# Episode 880, Total Reward: -1364.0749999999998
# Episode 881, Total Reward: -1470.0749999999996
# Episode 882, Total Reward: -1508.15
# Episode 883, Total Reward: -1624.4749999999997
# Episode 884, Total Reward: -1719.675
# Episode 885, Total Reward: -1761.2749999999996
# Episode 886, Total Reward: -2851.1
# Episode 887, Total Reward: -9259.375
# Episode 888, Total Reward: -1757.9
# Episode 889, Total Reward: -2108.8000000000006
# Episode 890, Total Reward: -1776.3749999999995
# Episode 891, Total Reward: -1620.1249999999998
# Episode 892, Total Reward: -1898.5999999999997
# Episode 893, Total Reward: -2754.6499999999996
# Episode 894, Total Reward: -1604.5
# Episode 895, Total Reward: -2499.100000000001
# Episode 896, Total Reward: -2054.4750000000004
# Episode 897, Total Reward: -2514.65
# Episode 898, Total Reward: -1530.3499999999997
# Episode 899, Total Reward: -1644.3749999999995
# Episode 900, Total Reward: -1953.7999999999997
# Episode 901, Total Reward: -2233.475
# Episode 902, Total Reward: -1806.175
# Episode 903, Total Reward: -1605.8249999999996
# Episode 904, Total Reward: -2459.5000000000005
# Episode 905, Total Reward: -1338.725
# Episode 906, Total Reward: -8121.525
# Episode 907, Total Reward: -3271.625
# Episode 908, Total Reward: -1747.5500000000004
# Episode 909, Total Reward: -2737.2
# Episode 910, Total Reward: -1405.9499999999998
# Episode 911, Total Reward: -2422.7499999999995
# Episode 912, Total Reward: -6043.174999999998
# Episode 913, Total Reward: -1672.75
# Episode 914, Total Reward: -1677.1749999999997
# Episode 915, Total Reward: -1833.25
# Episode 916, Total Reward: -1834.0000000000005
# Episode 917, Total Reward: -1917.1999999999994
# Episode 918, Total Reward: -1343.8750000000002
# Episode 919, Total Reward: -2177.0749999999994
# Episode 920, Total Reward: -1602.8750000000005
# Episode 921, Total Reward: -1541.0249999999996
# Episode 922, Total Reward: -3000.9500000000003
# Episode 923, Total Reward: -1456.2749999999994
# Episode 924, Total Reward: -2030.6000000000001
# Episode 925, Total Reward: -1654.625
# Episode 926, Total Reward: -1873.6000000000004
# Episode 927, Total Reward: -1461.9999999999998
# Episode 928, Total Reward: -1607.9750000000001
# Episode 929, Total Reward: -1369.425
# Episode 930, Total Reward: -1760.925
# Episode 931, Total Reward: -1687.3749999999998
# Episode 932, Total Reward: -1696.1
# Episode 933, Total Reward: -1706.4000000000003
# Episode 934, Total Reward: -1553.6750000000002
# Episode 935, Total Reward: -2188.1749999999993
# Episode 936, Total Reward: -1730.1750000000006
# Episode 937, Total Reward: -1480.7
# Episode 938, Total Reward: -1657.7499999999998
# Episode 939, Total Reward: -2526.225
# Episode 940, Total Reward: -1724.9250000000002
# Episode 941, Total Reward: -1199.775
# Episode 942, Total Reward: -1930.1749999999995
# Episode 943, Total Reward: -1871.9000000000003
# Episode 944, Total Reward: -1741.5249999999996
# Episode 945, Total Reward: -2445.6
# Episode 946, Total Reward: -1868.8249999999998
# Episode 947, Total Reward: -1568.35
# Episode 948, Total Reward: -1632.5499999999997
# Episode 949, Total Reward: -2325.2500000000005
# Episode 950, Total Reward: -2209.2000000000003
# Episode 951, Total Reward: -1767.6499999999999
# Episode 952, Total Reward: -5051.075000000003
# Episode 953, Total Reward: -2186.7500000000005
# Episode 954, Total Reward: -2259.674999999999
# Episode 955, Total Reward: -1163.0500000000002
# Episode 956, Total Reward: -1829.2
# Episode 957, Total Reward: -1401.4499999999994
# Episode 958, Total Reward: -1768.4250000000004
# Episode 959, Total Reward: -1486.5249999999996
# Episode 960, Total Reward: -1387.3000000000002
# Episode 961, Total Reward: -1844.7499999999998
# Episode 962, Total Reward: -1577.7749999999996
# Episode 963, Total Reward: -2474.4500000000016
# Episode 964, Total Reward: -1459.4500000000005
# Episode 965, Total Reward: -1363.5249999999999
# Episode 966, Total Reward: -1597.8750000000005
# Episode 967, Total Reward: -1319.9499999999998
# Episode 968, Total Reward: -1439.475
# Episode 969, Total Reward: -1959.6250000000005
# Episode 970, Total Reward: -1171.8
# Episode 971, Total Reward: -1440.8750000000005
# Episode 972, Total Reward: -1489.625
# Episode 973, Total Reward: -1732.0750000000007
# Episode 974, Total Reward: -1701.275
# Episode 975, Total Reward: -1351.525
# Episode 976, Total Reward: -2280.1749999999997

# %%
torch.save(agent.qnetwork.state_dict(), "dqn_inventory.pth")

# %%
# Save the trained model
torch.save(agent.qnetwork.state_dict(), "dqn_inventory.pth")

# Required run_policy function for leaderboard
def run_policy(state):
    # state: list of floats
    state_tensor = torch.FloatTensor(state).unsqueeze(0)
    with torch.no_grad():
        q_values = agent.qnetwork(state_tensor)
    action_idx = torch.argmax(q_values).item()
    orders = np.unravel_index(action_idx, (11, 11, 11))
    return [o * 10 for o in orders]

# %%
#rl_agent.py
#import gym
import subprocess
import sys
try:
    import torch
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "torch"])
import torch
import torch.nn as nn
import numpy as np
import os

# Get the current directory of submission.py
CURRENT_DIR = os.path.dirname(os.path.abspath(__file__))

# Path to the model file
model_path = os.path.join(CURRENT_DIR, "dqn_inventory.pth")

# # Load model content
# with open(model_path, 'r') as f:
#     model_data = f.read()

# # Optionally, process the model data
# print("Loaded model data:", model_data)

class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, hidden_size=128):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.out(x)

class RLAgent:
    def __init__(self):
        pass

    def flatten_state(self, state):
      if isinstance(state, dict):
          return np.concatenate([np.array(v, dtype=np.float32) for v in state.values()])
      return np.array(state, dtype=np.float32)

    def run_policy(self,state):
        state = self.flatten_state(state)
        STATE_SIZE = len(state)  # Example: adjust to your actual flattened state size
        ACTION_SIZE = 11 ** 3  # 3 products, 11 discrete actions each

        policy_net = QNetwork(STATE_SIZE, ACTION_SIZE)
        policy_net.load_state_dict(torch.load(model_path))
        policy_net.eval()
        state_tensor = torch.FloatTensor(state).unsqueeze(0)

        with torch.no_grad():
            q_values = policy_net(state_tensor)
        action_idx = torch.argmax(q_values).item()

        # Convert flat index → orders for 3 products
        orders = np.unravel_index(action_idx, (11, 11, 11))
        return [o * 10 for o in orders]  # since action space is {0,10,...,100}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3573362847.py in <cell line: 0>()
#       5
#       6 # Get the current directory of submission.py
# ----> 7 CURRENT_DIR = os.path.dirname(os.path.abspath(__file__))
#       8
#       9 # Path to the model file
#
# NameError: name '__file__' is not defined
