# %%
# %pip install lightgbm pytorch-tabnet
# Out:
# Requirement already satisfied: lightgbm in d:\applications\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: pytorch-tabnet in d:\applications\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17.0 in d:\applications\anaconda3\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in d:\applications\anaconda3\lib\site-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: scikit_learn>0.21 in d:\applications\anaconda3\lib\site-packages (from pytorch-tabnet) (1.4.2)
# Requirement already satisfied: torch>=1.3 in d:\applications\anaconda3\lib\site-packages (from pytorch-tabnet) (2.6.0)
# Requirement already satisfied: tqdm>=4.36 in d:\applications\anaconda3\lib\site-packages (from pytorch-tabnet) (4.66.4)
# Requirement already satisfied: joblib>=1.2.0 in d:\applications\anaconda3\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\applications\anaconda3\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (2.2.0)
# Requirement already satisfied: filelock in d:\applications\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\applications\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (4.13.2)
# Requirement already satisfied: networkx in d:\applications\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.2.1)
# Requirement already satisfied: jinja2 in d:\applications\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in d:\applications\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (2024.3.1)
# Requirement already satisfied: setuptools in d:\applications\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in d:\applications\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\applications\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: colorama in d:\applications\anaconda3\lib\site-packages (from tqdm>=4.36->pytorch-tabnet) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\applications\anaconda3\lib\site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np 

import lightgbm as lgb

from sklearn.model_selection import KFold

from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
trd = pd.read_csv('train.csv')
ted = pd.read_csv('test.csv')

# %%
X = trd.drop(['Status'],axis=1)
y = trd['Status']

# %%
model = lgb.LGBMClassifier()

# %%
from sklearn.preprocessing import OrdinalEncoder

# Create a list of categorical columns to be encoded
categorical_cols = ['Drug', 'Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema']

# Create an OrdinalEncoder instance
encoder = OrdinalEncoder()

# Fit the encoder on the training data for the specified columns
encoder.fit(X[categorical_cols])

# Transform both training and test data using the fitted encoder
X[categorical_cols] = encoder.transform(X[categorical_cols])
ted[categorical_cols] = encoder.transform(ted[categorical_cols])

# %%
param_grid = {
    'num_leaves': [30, 50, 100],
    'learning_rate': [0.01, 0.1,0.2, 0.5],
    'n_estimators': [100, 500, 1000],
}

# hyper parameter tuning 
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='accuracy', cv=5, n_jobs=-1)  
grid_search.fit(X, y)  

print("Best parameters found: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001835 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2228
# [LightGBM] [Info] Number of data points in the train set: 15000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.395416
# [LightGBM] [Info] Start training from score -3.724161
# [LightGBM] [Info] Start training from score -1.195784
# Best parameters found:  {'learning_rate': 0.01, 'n_estimators': 100, 'num_leaves': 100}
# Best score:  0.8470666666666666

# %%
best_model_lgbm = lgb.LGBMClassifier(**grid_search.best_params_)
best_model_lgbm.fit(X, y)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003925 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2228
# [LightGBM] [Info] Number of data points in the train set: 15000, number of used features: 19
# [LightGBM] [Info] Start training from score -0.395416
# [LightGBM] [Info] Start training from score -3.724161
# [LightGBM] [Info] Start training from score -1.195784
# LGBMClassifier(learning_rate=0.01, num_leaves=100)

# %%
y_pred_proba_LGBM = best_model_lgbm.predict_proba(ted)

# %%
def create_submission_file(y_pred_proba,X_test,model):
  submission_df = pd.DataFrame(y_pred_proba, columns=['Status_C', 'Status_CL','Status_D'])

  # Concatenate the 'id' column from X_test to the predictions DataFrame
  submission_df['id'] = X_test['id'].values

  # Reorder columns to have 'id' as the first column
  submission_df = submission_df[['id', 'Status_C', 'Status_CL','Status_D']]

  # Display the first few rows of the submission DataFrame
  print(submission_df.head())

  # Save the submission file
  submission_df.to_csv(f'submission_{model}.csv', index=False)

# %%
create_submission_file(y_pred_proba=y_pred_proba_LGBM,X_test=ted,model='LightGBM')
# Out:
#       id  Status_C  Status_CL  Status_D
# 0  15000  0.844955   0.021259  0.133786
# 1  15001  0.716081   0.013248  0.270672
# 2  15002  0.887399   0.012985  0.099616
# 3  15003  0.427267   0.355488  0.217245
# 4  15004  0.230409   0.011657  0.757934

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.preprocessing import LabelEncoder

# Install pytorch_tabnet if needed (uncomment if not already installed)
# %pip install pytorch-tabnet

y_train = y
X_train = X
X_test = ted
# Encode the target labels for TabNet training
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)

# Convert DataFrames to numpy arrays and ensure the data type is float32 for TabNet
X_train_np = X_train.values.astype(np.float32)
X_test_np = X_test.values.astype(np.float32)

# Define and train the TabNet classifier
tabnet_model = TabNetClassifier()

tabnet_model.fit(
    X_train_np, y_train_enc,
    eval_set=[(X_train_np, y_train_enc)],
    eval_metric=['accuracy'],
    max_epochs=100,
    patience=10,
    batch_size=1024,
    virtual_batch_size=128,
    num_workers=0,
    drop_last=False
)

# Predict probabilities on the test set
y_pred_proba_tabnet = tabnet_model.predict_proba(X_test_np)

# Map the predicted probabilities to columns.
# If the number of classes is two, we create two status columns; otherwise, we use three.
if len(le.classes_) == 2:
    columns = [f'Status_{cls}' for cls in le.classes_]
else:
    columns = ['Status_C', 'Status_CL', 'Status_D']

# Create a submission DataFrame using the same format as before
submission_df = pd.DataFrame(y_pred_proba_tabnet, columns=columns)
submission_df['id'] = X_test['id'].values
submission_df = submission_df[['id'] + columns]

print(submission_df.head())
submission_df.to_csv('submission_TabNet.csv', index=False)
# Out:
# d:\Applications\Anaconda3\Lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 21
#      18 # Define and train the TabNet classifier
#      19 tabnet_model = TabNetClassifier()
# ---> 21 tabnet_model.fit(
#      22     X_train_np, y_train_enc,
#      23     eval_set=[(X_train_np, y_train_enc)],
#      24     eval_metric=['accuracy'],
#      25     max_epochs=100,
#      26     patience=10,
#      27     batch_size=1024,
#      28     virtual_batch_size=128,
#      29     num_workers=0,
#      30     drop_last=False
#      31 )
#      33 # Predict probabilities on the test set
#      34 y_pred_proba_tabnet = tabnet_model.predict_proba(X_test_np)
#
# File d:\Applications\Anaconda3\Lib\site-packages\pytorch_tabnet\abstract_model.py:217, in TabModel.fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised, warm_start, augmentations, compute_importance)
#     214 else:
#     215     self.loss_fn = loss_fn
# --> 217 check_input(X_train)
#     218 check_warm_start(warm_start, from_unsupervised)
#     220 self.update_fit_params(
#     221     X_train,
#     222     y_train,
#     223     eval_set,
#     224     weights,
#     225 )
#
# File d:\Applications\Anaconda3\Lib\site-packages\pytorch_tabnet\utils.py:507, in check_input(X)
#     505     err_message = "Pandas DataFrame are not supported: apply X.values when calling fit"
#     506     raise TypeError(err_message)
# --> 507 check_array(X, accept_sparse=True)
#
# File d:\Applications\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File d:\Applications\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File d:\Applications\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.
